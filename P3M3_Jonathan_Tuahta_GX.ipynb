# %% [markdown]
# # Intro
# - Nama: Jonathan Tuahta
# - Batch: BSD-002
# - Objective: This files purpose is to make Great Expectation as validation for the data

# %%
from great_expectations.data_context import FileDataContext

context = FileDataContext.create(project_root_dir='./')

# %%
# Give a name to a Datasource. This name must be unique between Datasources.
datasource_name = 'csv-data-jan'
datasource = context.sources.add_pandas(datasource_name)

# Give a name to a data asset
asset_name = 'trip-january'
path_to_data = r'C:\Users\Jonathan T\OneDrive\文档\bootcamp\phase 2\p2-ftds002-bsd-m3-JoenathanT\P2M3_Jonathan_Tuahta_clean.csv'
# asset = datasource.add_csv_asset(asset_name, filepath_or_buffer=path_to_data, encoding= 'utf-8')
asset = datasource.add_csv_asset(asset_name, filepath_or_buffer=path_to_data, encoding='utf-8')


# Build batch request
batch_request = asset.build_batch_request()
# Out:
# 'T\\OneDrive\\文档\\bootcamp\\phase'
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# c:\Users\Jonathan T\OneDrive\文档\bootcamp\phase 2\p2-ftds002-bsd-m3-JoenathanT\P3M3_Jonathan_Tuahta_GX.ipynb Cell 3 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/Jonathan%20T/OneDrive/%E6%96%87%E6%A1%A3/bootcamp/phase%202/p2-ftds002-bsd-m3-JoenathanT/P3M3_Jonathan_Tuahta_GX.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> path_to_data = r'C:\Users\Jonathan T\OneDrive\文档\bootcamp\phase 2\p2-ftds002-bsd-m3-JoenathanT\P2M3_Jonathan_Tuahta_clean.csv'
#       <a href='vscode-notebook-cell:/c%3A/Users/Jonathan%20T/OneDrive/%E6%96%87%E6%A1%A3/bootcamp/phase%202/p2-ftds002-bsd-m3-JoenathanT/P3M3_Jonathan_Tuahta_GX.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> # asset = datasource.add_csv_asset(asset_name, filepath_or_buffer=path_to_data, encoding= 'utf-8')
# ...

# %%
# Give a name to a Datasource. This name must be unique between Datasources.
datasource_name = 'csv_electric_data'
datasource = context.sources.add_pandas(datasource_name)

# Give a name to a data asset
asset_name = 'Electric_car_analysis_data'
# path_to_data = "C:/Users/Jonathan T/OneDrive/文档/bootcamp/phase 2/p2-ftds002-bsd-m3-JoenathanT/P2M3_Jonathan_Tuahta_clean.csv"
path_to_data = r"C:/Users/Jonathan T/OneDrive/文档/bootcamp/phase 2/p2-ftds002-bsd-m3-JoenathanT/P2M3_Jonathan_Tuahta_clean.csv"

asset = datasource.add_csv_asset(asset_name, filepath_or_buffer=path_to_data)

# Build batch request
batch_request = asset.build_batch_request()
# Out:
# ---------------------------------------------------------------------------
# DataContextError                          Traceback (most recent call last)
# c:\Users\Jonathan T\OneDrive\文档\bootcamp\phase 2\p2-ftds002-bsd-m3-JoenathanT\P3M3_Jonathan_Tuahta_GX.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Jonathan%20T/OneDrive/%E6%96%87%E6%A1%A3/bootcamp/phase%202/p2-ftds002-bsd-m3-JoenathanT/P3M3_Jonathan_Tuahta_GX.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Give a name to a Datasource. This name must be unique between Datasources.
#       <a href='vscode-notebook-cell:/c%3A/Users/Jonathan%20T/OneDrive/%E6%96%87%E6%A1%A3/bootcamp/phase%202/p2-ftds002-bsd-m3-JoenathanT/P3M3_Jonathan_Tuahta_GX.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> datasource_name = 'csv_electric_data'
# ...

# %%
#create an expectation suite
expectation_suite_name = 'expectation-electric-car-dataset'
context.add_or_update_expectation_suite(expectation_suite_name)

validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name= expectation_suite_name
)

validator.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Jonathan T\OneDrive\文档\bootcamp\phase 2\p2-ftds002-bsd-m3-JoenathanT\P3M3_Jonathan_Tuahta_GX.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Jonathan%20T/OneDrive/%E6%96%87%E6%A1%A3/bootcamp/phase%202/p2-ftds002-bsd-m3-JoenathanT/P3M3_Jonathan_Tuahta_GX.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> expectation_suite_name = 'expectation-electric-car-dataset'
#       <a href='vscode-notebook-cell:/c%3A/Users/Jonathan%20T/OneDrive/%E6%96%87%E6%A1%A3/bootcamp/phase%202/p2-ftds002-bsd-m3-JoenathanT/P3M3_Jonathan_Tuahta_GX.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> context.add_or_update_expectation_suite(expectation_suite_name)
# ...
